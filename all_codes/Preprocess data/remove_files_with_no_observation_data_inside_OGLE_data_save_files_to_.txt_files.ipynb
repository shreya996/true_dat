# %%
import pandas as pd
import glob


file_list = glob.glob("/home/dic/jupyter/OGLE4_.dat_files/RRLYR" + "/*.dat")
#print(file_list)
df = pd.DataFrame()
d=0
for ijk in file_list:
    frame = pd.read_csv(ijk, sep=" ",names=["MJD","Mag","Mag_err"])
    #df = df.append(frame)
    abc=frame.dropna()
    abc1=abc.round({'Mag': 6,'MJD':6})
    #print (abc)
    abc1.to_csv('/home/dic/jupyter/OGLE4_.txt_files/RRLYR/RRLYR%d.txt' %d,encoding='utf-8',header=None,index=False)
    d+=1
#print (df)
#df.dropna()


#result5=df.dropna()
#print(result5)

# %%
import pandas as pd
import glob
import os

file_list = os.listdir("/home/dic/jupyter/testRR/")
                      
print(file_list)
# Out:
# ['OGLE-BLG-RRLYR-04533.dat', 'OGLE-BLG-RRLYR-12779.dat', 'OGLE-BLG-RRLYR-12063.dat', 'OGLE-BLG-RRLYR-04810.dat', 'OGLE-BLG-RRLYR-13522.dat', 'OGLE-LMC-RRLYR-01952.dat', 'OGLE-BLG-RRLYR-14943.dat', 'OGLE-BLG-RRLYR-06546.dat', 'OGLE-BLG-RRLYR-12059.dat', 'OGLE-BLG-RRLYR-15516.dat', 'OGLE-BLG-RRLYR-08283.dat', 'OGLE-LMC-RRLYR-01417.dat', 'OGLE-BLG-RRLYR-12216.dat', 'OGLE-BLG-RRLYR-07405.dat', 'OGLE-BLG-RRLYR-11814.dat', 'OGLE-LMC-RRLYR-01798.dat', 'OGLE-LMC-RRLYR-01199.dat', 'OGLE-LMC-RRLYR-02464.dat', 'OGLE-BLG-RRLYR-08573.dat', 'OGLE-BLG-RRLYR-13433.dat', 'OGLE-LMC-RRLYR-00637.dat', 'OGLE-BLG-RRLYR-10170.dat', 'OGLE-BLG-RRLYR-08919.dat', 'OGLE-BLG-RRLYR-12508.dat', 'OGLE-LMC-RRLYR-00629.dat', 'OGLE-BLG-RRLYR-10747.dat', 'OGLE-BLG-RRLYR-02053.dat', 'OGLE-BLG-RRLYR-03818.dat', 'OGLE-BLG-RRLYR-14669.dat', 'OGLE-LMC-RRLYR-00974.dat', 'OGLE-BLG-RRLYR-14342.dat', 'OGLE-BLG-RRLYR-12612.dat', 'OGLE-BLG-RRLYR-15336.dat', 'OGLE-BLG-RRLYR-09164.dat', 'OGLE-BLG-RRLYR-04173.dat', 'OGLE-LMC-RRLYR-0
# ...

# %%
file_list = glob.glob("/home/dic/jupyter/testRR" + "/*.dat")
print(file_list)
# Out:
# ['/home/dic/jupyter/testRR/OGLE-BLG-RRLYR-00012.dat', '/home/dic/jupyter/testRR/OGLE-BLG-RRLYR-00006.dat', '/home/dic/jupyter/testRR/OGLE-BLG-RRLYR-00017.dat', '/home/dic/jupyter/testRR/OGLE-BLG-RRLYR-00015.dat', '/home/dic/jupyter/testRR/OGLE-BLG-RRLYR-00005.dat', '/home/dic/jupyter/testRR/OGLE-BLG-RRLYR-00016.dat', '/home/dic/jupyter/testRR/OGLE-BLG-RRLYR-00001.dat', '/home/dic/jupyter/testRR/OGLE-BLG-RRLYR-00007.dat', '/home/dic/jupyter/testRR/OGLE-BLG-RRLYR-00010.dat', '/home/dic/jupyter/testRR/OGLE-BLG-RRLYR-00004.dat', '/home/dic/jupyter/testRR/OGLE-BLG-RRLYR-00013.dat', '/home/dic/jupyter/testRR/OGLE-BLG-RRLYR-00014.dat', '/home/dic/jupyter/testRR/OGLE-BLG-RRLYR-00002.dat', '/home/dic/jupyter/testRR/OGLE-BLG-RRLYR-00009.dat', '/home/dic/jupyter/testRR/OGLE-BLG-RRLYR-00008.dat', '/home/dic/jupyter/testRR/OGLE-BLG-RRLYR-00011.dat', '/home/dic/jupyter/testRR/OGLE-BLG-RRLYR-00003.dat']
