# %%
import pandas as pd
data=pd.read_csv('C:\\Users\\Shreya choudhary\\ecsvfile.txt', sep=" ",names=["Catalina_Surveys_ID","Numerical_ID","RA_(J2000)"," Dec ","V_(mag)","Period_(days)","Amplitude","Number_Obs","Var_Type"])
df2=data.loc[data['Var_Type'] == 13,'Numerical_ID']
df2.to_csv('OBJID13.txt', encoding='utf-8',index=False)
print(df2)
# Out:
# 174      1018002041429
# 328      1018002024540
# 331      1004003007536
# 648      1001004022706
# 680      1101004023765
# 714      1007004045838
# 734      1101004040815
# 771      1004004020792
# 944      1140004063774
# 1019     1140004077280
# 1161     1004005033484
# 1426     1138005036493
# 1497     1101006040068
# 1505     1143005097679
# 1510     1101006043962
# 1514     1009006034854
# 1547     1112006027308
# 2004     1123007062902
# 2064     1118008014972
# 2178     1143006041301
# 2250     1132007016744
# 2283     1146006025520
# 2470     1001009050644
# 2686     1012010013593
# 2689     1001010036427
# 2975     1138009061338
# 3053     1109011024797
# 3063     1132010071355
# 3329     1112012008965
# 3423     1123012010302
#              ...
# 44200    1001121052407
# 44235    1123112082710
# 44295    1007121015986
# 44335    1004122045886
# 44693    1015119047755
# 44808    1123113003726
# 44825    1018118027928
# 44985    1129109068435
# 45051    1135102046191
# ...
